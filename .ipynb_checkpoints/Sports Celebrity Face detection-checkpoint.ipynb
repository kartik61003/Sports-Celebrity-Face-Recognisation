# %%
import numpy as np
import cv2 as cv
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv.imread('./dataset/virat_kohli/v.jpg')
img.shape
# Out:
# (1038, 1600, 3)

# %%
plt.imshow(img)

# %%
grey = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
grey.shape
grey
plt.imshow(grey, cmap ='gray')

# %%
haar_cascade = cv.CascadeClassifier('./openCV/haarcascade_frontalface_default.xml')

# %%
faces_rect = haar_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 faces_rect = haar_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=9)
#
# NameError: name 'gray' is not defined

# %%
for (x, y, w, h) in faces_rect: 
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), thickness=2) 
  
cv.imshow('Detected faces', img) 
cv.waitKey(0)
